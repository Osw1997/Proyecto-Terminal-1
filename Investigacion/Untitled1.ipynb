# %%
import pandas as pd

# %%
df = pd.read_excel('SPARQLenpoints.xlsx')

# %%
df
# Out:
#           Palabra Nombre repositorio  \
# 0        geometry       europeandata
# 1        geometry       europeandata
# 2        geometry       europeandata
# 3        geometry            datahub
# 4        geometry            datahub
# ..            ...                ...
# 147  geographical            datahub
# 148  geographical       europeandata
# 149  geographical            datahub
# 150  geographical            datahub
# 151  geographical       europeandata
#
#                                         Nombre dataset  \
# 0    http-datos-gob-es-catalogo-l01100377-caminos-p...
# 1    http-datos-gob-es-catalogo-l01100377-barrios-c...
# 2    http-datos-gob-es-catalogo-l01100377-vias-urba...
# 3                          ordnance-survey-linked-data
# 4                                        geolinkeddata
# ..                                                 ...
# 147                                              aemet
# 148                                         libraries6
# ...

# %%
# Se hace un summary de los datos
